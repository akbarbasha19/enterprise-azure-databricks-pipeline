# %% [markdown]
# - JOB: ecomm_end_to_end_pipeline
# -
# - Task 1 → Bronze Ingestion
# -         ↓
# - Task 2 → Silver Transformation (DQ Framework)
# -         ↓
# - Task 3 → Gold Modeling (Star Schema)
# -         ↓
# - Task 4 → Analytics Views Creation
# -

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS e_comm_databricks.pipeline_bronze;

CREATE SCHEMA IF NOT EXISTS e_comm_databricks.pipeline_silver;

CREATE SCHEMA IF NOT EXISTS e_comm_databricks.pipeline_gold;

CREATE SCHEMA IF NOT EXISTS e_comm_databricks.pipeline_analytics;
