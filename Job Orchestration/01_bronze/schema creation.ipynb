# %%
# %sql
CREATE SCHEMA e_comm_databricks.pipeline_bronze;
CREATE SCHEMA e_comm_databricks.pipeline_silver;
CREATE SCHEMA e_comm_databricks.pipeline_gold;
CREATE SCHEMA e_comm_databricks.pipeline_analytics;
